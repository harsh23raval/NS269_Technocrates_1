# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("E:/WinHackaton/worthydata/final1.csv")
df1.head()
# Out:
#    Unnamed: 0                   State_Name District_Name  Crop_Year  \
# 0           0  Andaman and Nicobar Islands      NICOBARS       2000
# 1           1  Andaman and Nicobar Islands      NICOBARS       2000
# 2           2  Andaman and Nicobar Islands      NICOBARS       2000
# 3           3  Andaman and Nicobar Islands      NICOBARS       2000
# 4           4  Andaman and Nicobar Islands      NICOBARS       2000
#
#         Season                 Crop    Area Production  Rainfall
# 0  Kharif                  Arecanut  1254.0       2000    2763.2
# 1  Kharif       Other Kharif pulses     2.0          1    2763.2
# 2  Kharif                      Rice   102.0        321    2763.2
# 3  Whole Year                Banana   176.0        641    2763.2
# 4  Whole Year             Cashewnut   720.0        165    2763.2

# %%
df1.shape
# Out:
# (77189, 9)

# %%
df1.groupby('Crop')['Crop'].agg('count')
# Out:
# Crop
# Apple                           4
# Arecanut                      483
# Arhar/Tur                    2186
# Ash Gourd                      44
# Bajra                         937
# Banana                       1171
# Barley                       1259
# Beans & Mutter(Vegetable)      26
# Beet Root                      16
# Ber                            11
# Bhindi                         83
# Bitter Gourd                   82
# Black pepper                  401
# Blackgram                      50
# Bottle Gourd                   33
# Brinjal                        84
# Cabbage                        19
# Cardamom                      275
# Carrot                         10
# Cashewnut                     635
# Cashewnut Raw                  14
# Castor seed                   841
# Cauliflower                    14
# Citrus Fruit                   55
# Coconut                       589
# Coffee                          6
# Cond-spcs other                18
# ...

# %%
df2 = df1[df1.Crop != 'other misc. pulses']

# %%
df2.groupby('Crop')['Crop'].agg('count')
# Out:
# Crop
# Apple                           4
# Arecanut                      483
# Arhar/Tur                    2186
# Ash Gourd                      44
# Bajra                         937
# Banana                       1171
# Barley                       1259
# Beans & Mutter(Vegetable)      26
# Beet Root                      16
# Ber                            11
# Bhindi                         83
# Bitter Gourd                   82
# Black pepper                  401
# Blackgram                      50
# Bottle Gourd                   33
# Brinjal                        84
# Cabbage                        19
# Cardamom                      275
# Carrot                         10
# Cashewnut                     635
# Cashewnut Raw                  14
# Castor seed                   841
# Cauliflower                    14
# Citrus Fruit                   55
# Coconut                       589
# Coffee                          6
# Cond-spcs other                18
# ...

# %%
df3 = df2[df2.Crop != 'Turnip']

# %%
df3.shape
# Out:
# (77180, 9)

# %%
df3
# Out:
#        Unnamed: 0                   State_Name District_Name  Crop_Year  \
# 0               0  Andaman and Nicobar Islands      NICOBARS       2000
# 1               1  Andaman and Nicobar Islands      NICOBARS       2000
# 2               2  Andaman and Nicobar Islands      NICOBARS       2000
# 3               3  Andaman and Nicobar Islands      NICOBARS       2000
# 4               4  Andaman and Nicobar Islands      NICOBARS       2000
# 5               5  Andaman and Nicobar Islands      NICOBARS       2000
# 6               6  Andaman and Nicobar Islands      NICOBARS       2000
# 7               7  Andaman and Nicobar Islands      NICOBARS       2000
# 8               8  Andaman and Nicobar Islands      NICOBARS       2000
# 9               9  Andaman and Nicobar Islands      NICOBARS       2000
# 10             10  Andaman and Nicobar Islands      NICOBARS       2001
# 11             11  Andaman and Nicobar Islands      NICOBARS       2001
# ...

# %%
df3.drop(['Unnamed: 0'],axis='columns')
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 0      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 7      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 10     Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 11     Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# ...

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0       0
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# Rainfall         0
# dtype: int64

# %%
df4 = df3.drop(['Unnamed: 0'],axis='columns')

# %%
df4
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 0      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 7      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 10     Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 11     Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# ...

# %%
df4['Crop_Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2010, 2007, 2008, 2009,
#        2011, 2012, 2013, 2014, 1997, 1998, 1999, 2015], dtype=int64)

# %%
df5 = df4[ df4['Crop_Year'] == 1997 ].index
 
# Delete these row indexes from dataFrame
df4.drop(df5 , inplace=True)

# %%
df4['Crop_Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2010, 2007, 2008, 2009,
#        2011, 2012, 2013, 2014, 1998, 1999, 2015], dtype=int64)

# %%
df4.shape
# Out:
# (74299, 8)

# %%
df5 = df4[ df4['Crop_Year'] == 1998 ].index
 
# Delete these row indexes from dataFrame
df4.drop(df5 , inplace=True)

# %%
df4.shape
# Out:
# (71072, 8)

# %%
df5 = df4[ df4['Crop_Year'] == 1999 ].index
 
# Delete these row indexes from dataFrame
df4.drop(df5 , inplace=True)

# %%
df4.shape
# Out:
# (67385, 8)

# %%
df4['Crop_Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2010, 2007, 2008, 2009,
#        2011, 2012, 2013, 2014, 2015], dtype=int64)

# %%
df4
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 0      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 7      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 10     Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 11     Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# ...

# %%
df4.groupby('Season')['Season'].agg('count')
# Out:
# Season
# Autumn          3137
# Kharif         21612
# Rabi           15282
# Summer          3911
# Whole Year     19309
# Winter          4134
# Name: Season, dtype: int64

# %%
3137+21612+15282+3911+19309+4134
# Out:
# 67385

# %%
df4.Area.unique()
# Out:
# array([1.2540e+03, 2.0000e+00, 1.0200e+02, ..., 1.0023e+04, 2.4195e+04,
#        3.5417e+04])

# %%
df4.Production.unique()
# Out:
# array(['2000', '1', '321', ..., '35035', '13643', '49689'], dtype=object)

# %%
df4.State_Name.unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Arunachal Pradesh', 'Bihar',
#        'Chhattisgarh', 'Himachal Pradesh', 'Jammu and Kashmir',
#        'Jharkhand', 'Kerala', 'Odisha', 'Punjab', 'Tamil Nadu',
#        'Uttarakhand'], dtype=object)

# %%
len(df4.Crop.unique())
# Out:
# 104

# %%
df4.Crop = df4.Crop.apply(lambda x: x.strip())

crop_stats = df4.groupby('Crop')['Crop'].agg('count').sort_values(ascending=False)
crop_stats
# Out:
# Crop
# Rice                         5094
# Maize                        4177
# Moong(Green Gram)            3281
# Urad                         2841
# Sesamum                      2415
# Wheat                        2283
# Sugarcane                    2243
# Potato                       2184
# Rapeseed &Mustard            2170
# Groundnut                    1983
# Ragi                         1876
# Arhar/Tur                    1853
# Horse-gram                   1814
# Gram                         1710
# Onion                        1419
# Small millets                1396
# Turmeric                     1369
# Dry chillies                 1364
# Masoor                       1283
# Peas & beans (Pulses)        1277
# Dry ginger                   1240
# Sunflower                    1231
# Sweet potato                 1130
# Barley                       1122
# Other Kharif pulses          1070
# Linseed                       989
# Banana                        965
# ...

# %%
len(crop_stats[crop_stats<=100])
# Out:
# 49

# %%
crop_stats_less_than_100 = crop_stats[crop_stats<=100]
crop_stats_less_than_100
# Out:
# Crop
# Jack Fruit                   96
# Pulses total                 95
# Pump Kin                     93
# Papaya                       90
# Guar seed                    89
# Brinjal                      84
# Bhindi                       83
# Bitter Gourd                 82
# Snak Guard                   82
# Ginger                       67
# Moth                         60
# Pineapple                    57
# Pome Fruit                   57
# Tomato                       55
# Citrus Fruit                 55
# Other Citrus Fruit           54
# Cucumber                     51
# Lab-Lab                      48
# Pome Granet                  45
# Total foodgrain              44
# Ash Gourd                    44
# Redish                       43
# Orange                       38
# Ribed Guard                  38
# Korra                        36
# Yam                          36
# Cowpea(Lobia)                34
# Bottle Gourd                 33
# Water Melon                  32
# ...

# %%
df4.Crop = df4.Crop.apply(lambda x: 'other_crops' if x in crop_stats_less_than_100 else x )

# %%
len(df4.Crop.unique())
# Out:
# 56

# %%
df4.Crop.unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Small millets', 'Wheat', 'Potato', 'Oilseeds total',
#        'other_crops', 'Bajra', 'Horse-gram', 'Jute', 'Mesta', 'Ragi',
#        'Sesamum', 'Barley', 'Gram', 'Khesari', 'Linseed', 'Masoor',
#        'Other  Rabi pulses', 'Peas & beans (Pulses)', 'Rapeseed &Mustard',
#        'Coriander', 'Garlic', 'Onion', 'Jowar', 'Sannhamp', 'Tobacco',
#        'Safflower', 'Castor seed', 'Soyabean', 'Niger seed',
#        'Cotton(lint)', 'Other Fresh Fruits', 'Other Vegetables',
#        'Other Cereals & Millets', 'Drum Stick', 'Mango', 'Cardamom'],
#       dtype=object)

# %%
df4
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 0      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 7      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 10     Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 11     Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# ...

# %%
len(df4.Crop.unique())
# Out:
# 56

# %%
df4.Crop.unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Small millets', 'Wheat', 'Potato', 'Oilseeds total',
#        'other_crops', 'Bajra', 'Horse-gram', 'Jute', 'Mesta', 'Ragi',
#        'Sesamum', 'Barley', 'Gram', 'Khesari', 'Linseed', 'Masoor',
#        'Other  Rabi pulses', 'Peas & beans (Pulses)', 'Rapeseed &Mustard',
#        'Coriander', 'Garlic', 'Onion', 'Jowar', 'Sannhamp', 'Tobacco',
#        'Safflower', 'Castor seed', 'Soyabean', 'Niger seed',
#        'Cotton(lint)', 'Other Fresh Fruits', 'Other Vegetables',
#        'Other Cereals & Millets', 'Drum Stick', 'Mango', 'Cardamom'],
#       dtype=object)

# %%
df4.to_csv('E:/WinHackaton/worthydata/final2.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-39-752ab8f25adb> in <module>
# ----> 1 df4.to_csv('E:/WinHackaton/worthydata/final2.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
# ...

# %%
df4
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 0      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 7      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 10     Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 11     Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# ...
